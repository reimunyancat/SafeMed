# %% [markdown]
# # 01 — DUR 기초 EDA
#
# 병용금기 / 노인주의 / 임부금기 / 효능군중복 / 용량·투여기간주의 각 마스터의 행 수·성분수·분포를 본다.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'backend'))
from app.data.csv_loader import load_all

# %%
data = load_all('../data/sample')
{k: len(v) for k, v in data.items()}

# %%
# TODO: 성분·효능군 분포·중첩 조합 수 등 시각화
