# %% [markdown]
# # 03 — GCN 임베딩 학습 결과 검사
#
# `backend/app/ml/train.py` 로 돌린 2-layer GCN 의 임베딩을 t-SNE 로 떨구고 효능군별
# 코큐(cohort) 이 붙는지 확인. cosine 이웃 조회 예도 넓어볼 수 있다.

# %%
import sys, torch
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent / 'backend'))
emb_path = Path('../data/processed/gcn_embeddings.pt')
emb = torch.load(emb_path) if emb_path.exists() else None
emb is None or emb.shape

# %%
# TODO: sklearn TSNE 로 2D 투영 → 산절도 그림, 효능군별 색상 구분
